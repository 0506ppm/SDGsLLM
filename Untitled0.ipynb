# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %ls /content/drive/MyDrive
# Out:
#  01A12B65-5D97-4261-B6B1-E034F5514B91.jpeg
#  0296F9E6-3CF7-4ABB-BF1E-B02B2EA1A4E4.jpeg
# '0312 劇本翻譯討論.gdoc'
# '0507 資料科學家分享 榆軒提供.gdoc'
# '0507 資料科學家咖啡月.gdoc'
#  0513幫高中生面試問題.gdoc
# '0520 行銷社課討論.gdoc'
# '0525 平台簡報社課.gdoc'
#  0613_FDD.pdf
#  0814_GDSC期初會議.gdoc
#  0AF863CB-B4FA-4AC9-A45F-469F12F17A3F.jpeg
#  0B3319E8-D6C4-4D21-94F7-957E2D8490F1.jpeg
#  111-1成績單.pdf
# '111-2 OOP'/
# '111-2 TM Officers 分工.gdoc'
# '111-2 TM VPPR工作表.docx'
# '111-2 文案.gdoc'
#  111經濟迎新Agenda.gsheet
# '112_01_12 Podcast訪綱.gdoc'
#  1121115_GDSC_資料科學家講座.gdoc
#  1121211_資管系專案發表.gdoc
# '1121 SAD'/
#  112-1_多元學習補助講座認列表.pdf
#  1-1～2-1講義解答.pdf
#  112-1資訊管理期末報告.gdoc
# '112-2值班時間統整 的副本.gdoc'
#  1123實習課題目.pdf
# '112年所得清單_春淑萍 (1).jpg'
#  112年所得清單_春淑萍.jpg
# '112年所得清單_陳家祥 (1).jpg'
#  112年所得清單_陳家祥.jpg
# '112年所得清單_陳臺寶 (1).jpg'
#  112年所得清單_陳臺寶.jpg
#  112資管宿營行政組會議紀錄.gdoc
#  112資管迎新/
# '113 04 22脫癮而出.gdoc'
#  113學年_平台續留調查表單.gform
# '113學年_平台續留調查表單 (Responses).gsheet'
# '114.04.25 新創咖啡月（Colega AI）.gdoc'
# ...

# %%
# %cd /content/drive/MyDrive/企業永續報告書LLM
# Out:
# /content/drive/.shortcut-targets-by-id/1PtbeW_K818D2h9eqPDC1vST1R_mMaSo3/企業永續報告書LLM

# %%
# %ls
# Out:
#  fine-tuned-models/                 'SDGsLLM＿Embedding Model訓練'
#  fine_tune_embedding_data/           SDGsLLM＿處理文本
#  llama_instruction_qa_dataset.json   simple_text.txt
#  LLM_Fine_Tune.ipynb                 sustainability_embedding_model/
#  qa_pairs.json                       Untitled0.ipynb

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/.shortcut-targets-by-id/1PtbeW_K818D2h9eqPDC1vST1R_mMaSo3/企業永續報告書LLM/.git/

# %%
# !git config --global user.email "0506ppm@gmail.com"

# %%
# !git config --global user.name "0506ppm"

# %%
# !git remote add origin https://0506ppm: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@github.com/0506ppm/SDGsLLM.git

# %%
# 假設你已經切到正確目錄
# 建立 .gitignore 檔案
with open(".gitignore", "w") as f:
    f.write("fine-tuned-models/\n")
    f.write("sustainability_embedding_model/\n")

# %%
# !git branch -M main

# %%
# !git pull
# Out:
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 134 (delta 57), reused 120 (delta 43), pack-reused 0 (from 0)
# Receiving objects: 100% (134/134), 18.48 MiB | 17.37 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# From https://github.com/0506ppm/SDGsLLM
#  * [new branch]      main       -> origin/main
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> main

# %%
# !git add .

# %%
# !git commit -m "initial commit"
# Out:
# [main 99bcc94] initial commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin main
# Out:
# To https://github.com/0506ppm/SDGsLLM.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/0506ppm/SDGsLLM.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
